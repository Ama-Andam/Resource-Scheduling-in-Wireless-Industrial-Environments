# %%
# In this project we are buiding a real-time scheduling simulator in Python.

# We would have 4 different sensors/tasks:
# 1. Ultrasonic Sensor (Ultra): period=200ms, wcet=3ms, deadline=200ms
# 2. Sound Sensor (Sound): period=2000ms, wcet=8ms, deadline=2000ms
# 3. PIR Sensor (PIR): period=500ms, wcet=1ms, deadline=100ms
# 4. Button Sensor (Button): period=500ms, wcet=1ms, deadline=150ms
